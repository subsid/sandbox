# %%
import matplotlib.pyplot as plt
import numpy as np
import csv 
from matplotlib import colors
from matplotlib.ticker import PercentFormatter


# Fixing random state for reproducibility
np.random.seed(19680801)

# %%
queries = []
counts = []
with open("/home/sid/Downloads/nsr_counts.csv") as f:
        lines = f.readlines()
        for line in lines:
            try:
                ct, query = line.strip().split(",", 1)
                counts.append(int(ct))
                queries.append(query)
            except:
                print("Whoops")
                print(line.strip().split(","))

                
lt_10 = list(filter(lambda x: x[0] < 10, zip(counts, queries)))
lt_10.sort(reverse=True)
random.shuffle(lt_10)
# Out:
# Whoops
# ['ct', 'query']
# Whoops
# ['']
# Whoops
# ['￼']
# Whoops
# ['']
# Whoops
# ['Cotyledon ladismithiensis ‘Variegata’ “Variegated Bear&#39;s Paw”"']
# Whoops
# ['']
# Whoops
# ['￼"']
# Whoops
# ['']
# Whoops
# ['view image 9 of 10￼']
# Whoops
# ['']
# Whoops
# ['view image 10 of 10￼']
# Whoops
# ['']
# Whoops
# ['Cute Japanese Style Milk Carton House"']
# Whoops
# ['']
# Whoops
# ['view image 2 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 3 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 4 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 5 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 6 of 6￼']
# Whoops
# ['']
# Whoops
# ['double strands pearl necklace"']
# Whoops
# ['']
# Whoops
# ['view image 2 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 3 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 4 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 5 of 6￼']
# Whoops
# ['']
# Whoops
# ['view image 6 of 6￼']
# Whoops
# ['']
# Whoops
# ['Mermaid Mandala Mouse Ears"']
# Whoops
# ...

# %%
## Write output to file
  
# data to be written row-wise in csv fil 
data = lt_10[:5000]
  
# opening the csv file in 'w+' mode 
file = open('lt_10.csv', 'w+', newline ='') 
  
# writing the data into the file 
with file:     
    write = csv.writer(file) 
    write.writerow(["Count", "Query"])
    write.writerows(data)

# %%
objects = ('0 - 10', '10 - 100', '100 - 1000', '1000+')
y_pos = np.arange(len(objects))
performance = np.array([2006682, 36704, 136, 53])
tot = np.sum(performance)
perc = (performance/ tot) * 100
print(perc)

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Count')
plt.title('NSR query counts')

plt.show()
# Out:
# [9.81946833e+01 1.79606816e+00 6.65500410e-03 2.59349424e-03]
