# %% [markdown]
# _Examples from https://matplotlib.org/users/pyplot_tutorial.html_
#
# - [Simple plot](#simple_plot)
# - [Modify line properties](#modify_line_properties)
# - [Working with multiple plots](#working_with_multiple_plots)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# <a id="simple_plot"></a>
#
# #### Simple plot

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
# Specify x and y range of axis
plt.axis([0, 6, 0, 20])
plt.xlabel("x-axis label")
plt.ylabel("y-axis label")
plt.show()
# Turn off axis
# plt.axis("off")

# %%
## Plot using numpy
t = np.arange(0, 5, 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# #### Modifying line properties
#
# <a id='modify_line_properties'></a>

# %%
t = np.arange(0, 5, 0.2)
line, = plt.plot(t, t**2)
# line.set_antialiased(False)
plt.setp(line, antialiased=False)
# matlab style
# plt.setp(line, 'antialiased', False)
plt.show()

# %% [markdown]
# #### Working with multiple plots
# <a id="working_with_multiple_plots"></a>

# %%
plt.figure(1)                # the first figure
plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
# The label here suppresses the warning and forces a new instance creation
plt.subplot(211, label="ax1") # make subplot(211) in figure1 current
plt.plot([10, 12, 14])
plt.title('Easy as 1, 2, 3') # subplot 211 title
plt.show()
